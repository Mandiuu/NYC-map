# %%
import pandas as pd

csv_path = "dataanddate.csv"
df = pd.read_csv(csv_path)

df.head()
# Out:
#   SUMMONS_DATE             CATEGORY  \
# 0   12/31/2023        ALCOHOL/DRUGS
# 1   12/31/2023        ALCOHOL/DRUGS
# 2   12/31/2023  DISORDERLY BEHAVIOR
# 3   12/31/2023  DISORDERLY BEHAVIOR
# 4   12/31/2023        ALCOHOL/DRUGS
#
#                                  OFFENSE_DESCRIPTION AGE_GROUP SEX  \
# 0                       ALCOHOLIC BEVERAGE IN PUBLIC     25-44   M
# 1                       ALCOHOLIC BEVERAGE IN PUBLIC     25-44   M
# 2  CREATES A HAZARDOUS OR PHYSICALLY OFFENSIVE CO...     25-44   F
# 3                                           TRESPASS     45-64   M
# 4                       ALCOHOLIC BEVERAGE IN PUBLIC     25-44   M
#
#              RACE       BORO  PRECINCT_OF_OCCUR  precinct  POPULATION
# 0           BLACK   BROOKLYN               75.0      47.0    200994.0
# 1  WHITE HISPANIC  MANHATTAN               14.0       8.0     28050.0
# 2           WHITE   BROOKLYN               72.0      45.0    133230.0
# ...

# %%
# Correct the property name in GeoJSON
geojson_precincts = [feature['properties']['precinct'] for feature in Precints.geojson['features']]

# Display both lists of precinct IDs
Precints.geojson, csv_precincts
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Correct the property name in GeoJSON
# ----> 2 geojson_precincts = [feature['properties']['precinct'] for feature in Precints.geojson['features']]
#       4 # Display both lists of precinct IDs
#       5 Precints.geojson, csv_precincts
#
# NameError: name 'Precints' is not defined
